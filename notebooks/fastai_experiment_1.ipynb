# %%
from fastai.tabular import *

# %%
dPath = Path("../docs/dumps")

# %%
with open(dPath / "train_data.pkl", 'rb') as filename:
    train_data = pickle.load(filename)

# %%
with open(dPath / "valid_data.pkl", 'rb') as filename:
    valid_data = pickle.load(filename)

# %%
with open(dPath / "not_running.pkl", 'rb') as filename:
    not_running = pickle.load(filename)

# %%
with open(dPath / "rf_exp_05_names.pkl", 'rb') as filename:
    names = pickle.load(filename)

# %%
len(valid_data)
# Out:
# 67496

# %%
all_df = pd.concat([train_data,valid_data],axis=0,ignore_index=True)

# %%
all_df['MutatorClass'] = all_df.MutatorClass.astype('category')

# %%
all_df['returnType'] = all_df.returnType.astype('category')

# %%
all_df.head().T.head(40)
# Out:
#                                       0         1         2         3  \
# numExecuted                          14        14        14        14
# MutatorClass                          2         6         6         0
# numAssertInTC                        14        14        14        14
# numTestCover                          1         1         1         1
# numAssertInTM                         7         7         7         7
# ppavcc                            2.125     2.125     2.125     2.125
# cchalsteadCumulativeBugs       0.593518  0.593518  0.593518  0.593518
# cchalsteadCumulativeVolume      1780.55   1780.55   1780.55   1780.55
# ppRVF                                13        13        13        13
# ppnumberOfMethods                    16        16        16        16
# ppnumberOfClasses                     5         5         5         5
# ppmaintainabilityIndexNC        97.1251   97.1251   97.1251   97.1251
# ppfanout                              2         2         2         2
# ccmaintainabilityIndex          67.4658   67.4658   67.4658   67.4658
# mmhalsteadDifficulty               13.2      13.2      13.2      13.2
# ppabstractness                        0         0         0         0
# ppmaintainabilityIndex          97.3608   97.3608   97.3608   97.3608
# mmnumberOfExpressions                 5         5         5         5
# ccexternalMethodCalls                 9         9         9         9
# mminstanceVariablesReferenced         0         0         0         0
# ccimportedPackages                    3         3         3         3
# ppdistance                     0.333333  0.333333  0.333333  0.333333
# returnType                            3         3         3         3
# ccnumberOfStatements                 49        49        49        49
# ccfanIn                               1         1         1         1
# ppfanin                               1         1         1         1
# pploc                               262       262       262       262
# ppnumberOfStatements                232       232       232       232
# cchalsteadEffort                  32644     32644     32644     32644
# ccmaintainabilityIndexNC        99.6875   99.6875   99.6875   99.6875
# mmhalsteadVocabulary                 21        21        21        21
# pptcc                                34        34        34        34
# mmexternalMethodsCalled               1         1         1         1
# ppinstability                  0.666667  0.666667  0.666667  0.666667
# ppmaxcc                               5         5         5         5
# mmhalsteadEffort                2782.97   2782.97   2782.97   2782.97
# mmvariablesReferenced                 3         3         3         3
# ccunweightedClassSize                 4         4         4         4
# Detected                           True      True      True      True
#
#                                       4
# numExecuted                          14
# MutatorClass                          0
# numAssertInTC                        14
# numTestCover                          1
# numAssertInTM                         7
# ppavcc                            2.125
# cchalsteadCumulativeBugs       0.593518
# cchalsteadCumulativeVolume      1780.55
# ppRVF                                13
# ppnumberOfMethods                    16
# ppnumberOfClasses                     5
# ppmaintainabilityIndexNC        97.1251
# ppfanout                              2
# ccmaintainabilityIndex          67.4658
# mmhalsteadDifficulty               13.2
# ppabstractness                        0
# ppmaintainabilityIndex          97.3608
# mmnumberOfExpressions                 5
# ccexternalMethodCalls                 9
# mminstanceVariablesReferenced         0
# ccimportedPackages                    3
# ppdistance                     0.333333
# returnType                            3
# ccnumberOfStatements                 49
# ccfanIn                               1
# ppfanin                               1
# pploc                               262
# ppnumberOfStatements                232
# cchalsteadEffort                  32644
# ccmaintainabilityIndexNC        99.6875
# mmhalsteadVocabulary                 21
# pptcc                                34
# mmexternalMethodsCalled               1
# ppinstability                  0.666667
# ppmaxcc                               5
# mmhalsteadEffort                2782.97
# mmvariablesReferenced                 3
# ccunweightedClassSize                 4
# Detected                           True

# %%
all_df = all_df[list(names) + ['Detected']]

# %%
procs = [Categorify, Normalize]

# %%
valid_idx = range(len(all_df) - len(valid_data), len(all_df))

# %%
dep_var = 'Detected'
cat_names = ['MutatorClass', 'returnType']

# %%
data = TabularDataBunch.from_df(dPath, all_df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=cat_names)

# %%
print(data.train_ds.cont_names)
# Out:
# ['ccexternalMethodCalls', 'ppRVF', 'mminstanceVariablesReferenced', 'pptcc', 'cchalsteadCumulativeVolume', 'mmhalsteadVocabulary', 'ppinstability', 'mmexternalMethodsCalled', 'numExecuted', 'numAssertInTM', 'mmhalsteadEffort', 'ppmaintainabilityIndex', 'ppmaintainabilityIndexNC', 'ppnumberOfClasses', 'ccimportedPackages', 'cchalsteadEffort', 'numTestCover', 'ccmaintainabilityIndex', 'numAssertInTC', 'ppfanout', 'ppnumberOfMethods', 'ppabstractness', 'ccfanIn', 'ppdistance', 'mmvariablesReferenced', 'ccnumberOfStatements', 'ppfanin', 'ccmaintainabilityIndexNC', 'mmhalsteadDifficulty', 'pploc', 'cchalsteadCumulativeBugs', 'ppmaxcc', 'ppnumberOfStatements', 'mmnumberOfExpressions', 'ppavcc', 'ccunweightedClassSize']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [[2 4]
#  [4 3]
#  [4 1]
#  [1 2]
#  [4 2]]
# [[ 0.257625  1.826909  0.315172  3.250626 ...  3.426991 -0.084125  0.010808 -0.249664]
#  [-0.414166 -0.527888 -0.22943  -0.422042 ... -0.403729 -0.134418 -0.29355  -0.458878]
#  [ 7.286848 -0.365488 -0.073829 -0.436656 ... -0.423042  0.263059  0.091559  0.081591]
#  [ 0.061003 -0.798554 -0.22943  -0.058226 ... -0.294622 -0.230137 -0.360684  0.988185]
#  [ 0.159314  1.989309 -0.22943  -0.154    ... -0.218368  0.282528  1.328326 -0.598353]]
# [1 1 1 1 0]

# %%
learn = tabular_learner(data, layers=[200,100], emb_szs={'MutatorClass': 8, 'returnType': 10}, metrics=accuracy)

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.458538</td>
#       <td>0.561120</td>
#       <td>0.737984</td>
#       <td>06:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict(all_df.iloc[0])
# Out:
# (Category True, tensor(1), tensor([0.1561, 0.8439]))

# %%
learn.save('fastai_exp_1')

# %%
learn.show_results(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>MutatorClass</th>
#       <th>returnType</th>
#       <th>ccexternalMethodCalls</th>
#       <th>ppRVF</th>
#       <th>mminstanceVariablesReferenced</th>
#       <th>pptcc</th>
#       <th>cchalsteadCumulativeVolume</th>
#       <th>mmhalsteadVocabulary</th>
#       <th>ppinstability</th>
#       <th>mmexternalMethodsCalled</th>
#       <th>numExecuted</th>
#       <th>numAssertInTM</th>
#       <th>mmhalsteadEffort</th>
#       <th>ppmaintainabilityIndex</th>
#       <th>ppmaintainabilityIndexNC</th>
#       <th>ppnumberOfClasses</th>
#       <th>ccimportedPackages</th>
#       <th>cchalsteadEffort</th>
#       <th>numTestCover</th>
#       <th>ccmaintainabilityIndex</th>
#       <th>numAssertInTC</th>
#       <th>ppfanout</th>
#       <th>ppnumberOfMethods</th>
#       <th>ppabstractness</th>
#       <th>ccfanIn</th>
#       <th>ppdistance</th>
#       <th>mmvariablesReferenced</th>
#       <th>ccnumberOfStatements</th>
#       <th>ppfanin</th>
#       <th>ccmaintainabilityIndexNC</th>
#       <th>mmhalsteadDifficulty</th>
#       <th>pploc</th>
#       <th>cchalsteadCumulativeBugs</th>
#       <th>ppmaxcc</th>
#       <th>ppnumberOfStatements</th>
#       <th>mmnumberOfExpressions</th>
#       <th>ppavcc</th>
#       <th>ccunweightedClassSize</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>3</td>
#       <td>-0.5944</td>
#       <td>-0.6362</td>
#       <td>-0.2294</td>
#       <td>-0.5240</td>
#       <td>-0.4275</td>
#       <td>-0.4678</td>
#       <td>1.0691</td>
#       <td>-0.2723</td>
#       <td>-0.0388</td>
#       <td>-0.0584</td>
#       <td>-0.1421</td>
#       <td>-0.1841</td>
#       <td>-0.4837</td>
#       <td>-0.5133</td>
#       <td>-0.6467</td>
#       <td>-0.1572</td>
#       <td>-0.2260</td>
#       <td>-0.8891</td>
#       <td>-0.0671</td>
#       <td>-0.6358</td>
#       <td>-0.5352</td>
#       <td>-0.9068</td>
#       <td>-0.2772</td>
#       <td>-0.4287</td>
#       <td>-0.4340</td>
#       <td>-0.4710</td>
#       <td>-0.4997</td>
#       <td>-0.1552</td>
#       <td>-0.2763</td>
#       <td>-0.5117</td>
#       <td>-0.4275</td>
#       <td>-0.5428</td>
#       <td>-0.5101</td>
#       <td>-0.2285</td>
#       <td>-0.1286</td>
#       <td>-0.5635</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3</td>
#       <td>-0.5944</td>
#       <td>-0.6362</td>
#       <td>-0.2294</td>
#       <td>-0.5240</td>
#       <td>-0.4275</td>
#       <td>-0.4678</td>
#       <td>1.0691</td>
#       <td>-0.2723</td>
#       <td>-0.0388</td>
#       <td>-0.0584</td>
#       <td>-0.1421</td>
#       <td>-0.1841</td>
#       <td>-0.4837</td>
#       <td>-0.5133</td>
#       <td>-0.6467</td>
#       <td>-0.1572</td>
#       <td>-0.2260</td>
#       <td>-0.8891</td>
#       <td>-0.0671</td>
#       <td>-0.6358</td>
#       <td>-0.5352</td>
#       <td>-0.9068</td>
#       <td>-0.2772</td>
#       <td>-0.4287</td>
#       <td>-0.4340</td>
#       <td>-0.4710</td>
#       <td>-0.4997</td>
#       <td>-0.1552</td>
#       <td>-0.2763</td>
#       <td>-0.5117</td>
#       <td>-0.4275</td>
#       <td>-0.5428</td>
#       <td>-0.5101</td>
#       <td>-0.2285</td>
#       <td>-0.1286</td>
#       <td>-0.5635</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3</td>
#       <td>-0.5944</td>
#       <td>-0.6362</td>
#       <td>-0.2294</td>
#       <td>-0.5240</td>
#       <td>-0.4275</td>
#       <td>-0.4678</td>
#       <td>1.0691</td>
#       <td>-0.2723</td>
#       <td>-0.0388</td>
#       <td>-0.0584</td>
#       <td>-0.1421</td>
#       <td>-0.1841</td>
#       <td>-0.4837</td>
#       <td>-0.5133</td>
#       <td>-0.6467</td>
#       <td>-0.1572</td>
#       <td>-0.2260</td>
#       <td>-0.8891</td>
#       <td>-0.0671</td>
#       <td>-0.6358</td>
#       <td>-0.5352</td>
#       <td>-0.9068</td>
#       <td>-0.2772</td>
#       <td>-0.4287</td>
#       <td>-0.4340</td>
#       <td>-0.4710</td>
#       <td>-0.4997</td>
#       <td>-0.1552</td>
#       <td>-0.2763</td>
#       <td>-0.5117</td>
#       <td>-0.4275</td>
#       <td>-0.5428</td>
#       <td>-0.5101</td>
#       <td>-0.2285</td>
#       <td>-0.1286</td>
#       <td>-0.5635</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>3</td>
#       <td>-0.5944</td>
#       <td>-0.6362</td>
#       <td>-0.2294</td>
#       <td>-0.5240</td>
#       <td>-0.4275</td>
#       <td>-0.4678</td>
#       <td>1.0691</td>
#       <td>-0.2723</td>
#       <td>-0.0388</td>
#       <td>-0.0584</td>
#       <td>-0.1421</td>
#       <td>-0.1841</td>
#       <td>-0.4837</td>
#       <td>-0.5133</td>
#       <td>-0.6467</td>
#       <td>-0.1572</td>
#       <td>-0.2260</td>
#       <td>-0.8891</td>
#       <td>-0.0671</td>
#       <td>-0.6358</td>
#       <td>-0.5352</td>
#       <td>-0.9068</td>
#       <td>-0.2772</td>
#       <td>-0.4287</td>
#       <td>-0.4340</td>
#       <td>-0.4710</td>
#       <td>-0.4997</td>
#       <td>-0.1552</td>
#       <td>-0.2763</td>
#       <td>-0.5117</td>
#       <td>-0.4275</td>
#       <td>-0.5428</td>
#       <td>-0.5101</td>
#       <td>-0.2285</td>
#       <td>-0.1286</td>
#       <td>-0.5635</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>3</td>
#       <td>-0.5944</td>
#       <td>-0.6362</td>
#       <td>-0.2294</td>
#       <td>-0.5240</td>
#       <td>-0.4275</td>
#       <td>-0.4678</td>
#       <td>1.0691</td>
#       <td>-0.2723</td>
#       <td>-0.0388</td>
#       <td>-0.0584</td>
#       <td>-0.1421</td>
#       <td>-0.1841</td>
#       <td>-0.4837</td>
#       <td>-0.5133</td>
#       <td>-0.6467</td>
#       <td>-0.1572</td>
#       <td>-0.2260</td>
#       <td>-0.8891</td>
#       <td>-0.0671</td>
#       <td>-0.6358</td>
#       <td>-0.5352</td>
#       <td>-0.9068</td>
#       <td>-0.2772</td>
#       <td>-0.4287</td>
#       <td>-0.4340</td>
#       <td>-0.4710</td>
#       <td>-0.4997</td>
#       <td>-0.1552</td>
#       <td>-0.2763</td>
#       <td>-0.5117</td>
#       <td>-0.4275</td>
#       <td>-0.5428</td>
#       <td>-0.5101</td>
#       <td>-0.2285</td>
#       <td>-0.1286</td>
#       <td>-0.5635</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.validate(learn.data.train_dl)
# Out:
# [0.5017549, tensor(0.7538)]

# %%
preds,y,losses = learn.get_preds(with_loss=True)

# %%
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.confusion_matrix()
# Out:
# array([[  984, 15673],
#        [ 2012, 48827]], dtype=int64)
