# %%
from fastai.tabular import *

# %%
dPath = Path("../docs/dumps")

# %%
with open(dPath / "train_data.pkl", 'rb') as filename:
    train_data = pickle.load(filename)

# %%
with open(dPath / "valid_data.pkl", 'rb') as filename:
    valid_data = pickle.load(filename)

# %%
with open(dPath / "not_running.pkl", 'rb') as filename:
    not_running = pickle.load(filename)

# %%
with open(dPath / "rf_exp_05_names.pkl", 'rb') as filename:
    names = pickle.load(filename)

# %%
len(valid_data)
# Out:
# 67496

# %%
all_df = pd.concat([train_data, not_running, valid_data],axis=0,ignore_index=True)

# %%
all_df['MutatorClass'] = all_df.MutatorClass.astype('category')

# %%
all_df['returnType'] = all_df.returnType.astype('category')

# %%
all_df.head().T.head(40)
# Out:
#                                          0         1         2         3  \
# Detected                              True      True      True      True
# MutatorClass                             2         6         6         0
# returnType                               3         3         3         3
# numExecuted                             14        14        14        14
# numTestCover                             1         1         1         1
# numAssertInTM                            7         7         7         7
# numAssertInTC                           14        14        14        14
# ppnumberOfClasses                        5         5         5         5
# ppnumberOfStatements                   232       232       232       232
# ppavcc                               2.125     2.125     2.125     2.125
# pphalsteadCumulativeBugs           2.63609   2.63609   2.63609   2.63609
# pphalsteadEffort                    136211    136211    136211    136211
# pphalsteadCumulativeLength            1632      1632      1632      1632
# pphalsteadCumulativeVolume         7908.27   7908.27   7908.27   7908.27
# ppmaintainabilityIndex             97.3608   97.3608   97.3608   97.3608
# ppcumulativeNumberOfCommentLines        69        69        69        69
# pploc                                  262       262       262       262
# ppRVF                                   13        13        13        13
# pptcc                                   34        34        34        34
# ppcumulativeNumberOfComments            16        16        16        16
# ppinstability                     0.666667  0.666667  0.666667  0.666667
# ppdistance                        0.333333  0.333333  0.333333  0.333333
# ppfanin                                  1         1         1         1
# ppnumberOfMethods                       16        16        16        16
# ppmaintainabilityIndexNC           97.1251   97.1251   97.1251   97.1251
# ppabstractness                           0         0         0         0
# ppmaxcc                                  5         5         5         5
# ppfanout                                 2         2         2         2
# ccnumberOfMethods                        4         4         4         4
# cclcom                                   0         0         0         0
# ccavcc                                   3         3         3         3
# ccnumberOfStatements                    49        49        49        49
# cchalsteadCumulativeBugs          0.593518  0.593518  0.593518  0.593518
# cchalsteadEffort                     32644     32644     32644     32644
# ccunweightedClassSize                    4         4         4         4
# ccinstanceVariables                      0         0         0         0
# ccimportedPackages                       3         3         3         3
# ccresponseForClass                       4         4         4         4
# cccbo                                    4         4         4         4
# ccmaintainabilityIndex             67.4658   67.4658   67.4658   67.4658
#
#                                          4
# Detected                              True
# MutatorClass                             0
# returnType                               3
# numExecuted                             14
# numTestCover                             1
# numAssertInTM                            7
# numAssertInTC                           14
# ppnumberOfClasses                        5
# ppnumberOfStatements                   232
# ppavcc                               2.125
# pphalsteadCumulativeBugs           2.63609
# pphalsteadEffort                    136211
# pphalsteadCumulativeLength            1632
# pphalsteadCumulativeVolume         7908.27
# ppmaintainabilityIndex             97.3608
# ppcumulativeNumberOfCommentLines        69
# pploc                                  262
# ppRVF                                   13
# pptcc                                   34
# ppcumulativeNumberOfComments            16
# ppinstability                     0.666667
# ppdistance                        0.333333
# ppfanin                                  1
# ppnumberOfMethods                       16
# ppmaintainabilityIndexNC           97.1251
# ppabstractness                           0
# ppmaxcc                                  5
# ppfanout                                 2
# ccnumberOfMethods                        4
# cclcom                                   0
# ccavcc                                   3
# ccnumberOfStatements                    49
# cchalsteadCumulativeBugs          0.593518
# cchalsteadEffort                     32644
# ccunweightedClassSize                    4
# ccinstanceVariables                      0
# ccimportedPackages                       3
# ccresponseForClass                       4
# cccbo                                    4
# ccmaintainabilityIndex             67.4658

# %%
all_df = all_df[list(names) + ['Detected']]

# %%
procs = [Categorify, Normalize]

# %%
valid_idx = range(len(all_df) - len(valid_data), len(all_df))

# %%
dep_var = 'Detected'
cat_names = ['MutatorClass', 'returnType']

# %%
data = TabularDataBunch.from_df(dPath, all_df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=cat_names)

# %%
learn = tabular_learner(data, layers=[200,100], emb_szs={'MutatorClass': 8, 'returnType': 10}, metrics=[accuracy,Precision(),Recall(),MatthewsCorreff(),AUROC()])

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(18, 8)
#     (1): Embedding(22, 10)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=54, out_features=200, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=200, out_features=100, bias=True)
#     (4): ReLU(inplace=True)
#     (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=100, out_features=2, bias=True)
#   )
# )

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>matthews_correff</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.476172</td>
#       <td>0.559476</td>
#       <td>0.748030</td>
#       <td>0.757450</td>
#       <td>0.978953</td>
#       <td>0.059511</td>
#       <td>0.606735</td>
#       <td>06:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.460821</td>
#       <td>0.560980</td>
#       <td>0.739466</td>
#       <td>0.761168</td>
#       <td>0.953186</td>
#       <td>0.075188</td>
#       <td>0.607747</td>
#       <td>07:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.431881</td>
#       <td>0.549366</td>
#       <td>0.743437</td>
#       <td>0.763546</td>
#       <td>0.955172</td>
#       <td>0.096789</td>
#       <td>0.626847</td>
#       <td>07:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.421758</td>
#       <td>0.548681</td>
#       <td>0.746326</td>
#       <td>0.767116</td>
#       <td>0.952320</td>
#       <td>0.122350</td>
#       <td>0.636090</td>
#       <td>07:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict(all_df.iloc[0])
# Out:
# (Category True, tensor(1), tensor([0.1561, 0.8439]))

# %%
learn.save('fastai_exp_3')

# %%
learn.show_results(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>MutatorClass</th>
#       <th>returnType</th>
#       <th>ccmaintainabilityIndex</th>
#       <th>ppdistance</th>
#       <th>ppfanout</th>
#       <th>ccexternalMethodCalls</th>
#       <th>mmhalsteadVocabulary</th>
#       <th>cchalsteadCumulativeVolume</th>
#       <th>pptcc</th>
#       <th>numAssertInTM</th>
#       <th>cchalsteadCumulativeBugs</th>
#       <th>mmnumberOfExpressions</th>
#       <th>ccmaintainabilityIndexNC</th>
#       <th>ppRVF</th>
#       <th>numExecuted</th>
#       <th>mmvariablesReferenced</th>
#       <th>numAssertInTC</th>
#       <th>ppmaintainabilityIndex</th>
#       <th>pploc</th>
#       <th>ccimportedPackages</th>
#       <th>ppnumberOfStatements</th>
#       <th>ppnumberOfMethods</th>
#       <th>ccunweightedClassSize</th>
#       <th>mmhalsteadDifficulty</th>
#       <th>ccfanIn</th>
#       <th>ppmaxcc</th>
#       <th>numTestCover</th>
#       <th>ppmaintainabilityIndexNC</th>
#       <th>cchalsteadEffort</th>
#       <th>ppabstractness</th>
#       <th>mminstanceVariablesReferenced</th>
#       <th>ppnumberOfClasses</th>
#       <th>mmexternalMethodsCalled</th>
#       <th>ppavcc</th>
#       <th>ppinstability</th>
#       <th>ccnumberOfStatements</th>
#       <th>mmhalsteadEffort</th>
#       <th>ppfanin</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>3.0</td>
#       <td>-0.8965</td>
#       <td>-0.4213</td>
#       <td>-0.6408</td>
#       <td>-0.5953</td>
#       <td>-0.4715</td>
#       <td>-0.4286</td>
#       <td>-0.5225</td>
#       <td>-0.0570</td>
#       <td>-0.4286</td>
#       <td>-0.2270</td>
#       <td>-0.1624</td>
#       <td>-0.6354</td>
#       <td>-0.0379</td>
#       <td>-0.4347</td>
#       <td>-0.0655</td>
#       <td>-0.1897</td>
#       <td>-0.5097</td>
#       <td>-0.6494</td>
#       <td>-0.5086</td>
#       <td>-0.5284</td>
#       <td>-0.5266</td>
#       <td>-0.2738</td>
#       <td>-0.2739</td>
#       <td>-0.5438</td>
#       <td>-0.2198</td>
#       <td>-0.4960</td>
#       <td>-0.1548</td>
#       <td>-0.8717</td>
#       <td>-0.2330</td>
#       <td>-0.5107</td>
#       <td>-0.2764</td>
#       <td>-0.1277</td>
#       <td>1.0448</td>
#       <td>-0.4711</td>
#       <td>-0.1395</td>
#       <td>-0.5013</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.0</td>
#       <td>-0.8965</td>
#       <td>-0.4213</td>
#       <td>-0.6408</td>
#       <td>-0.5953</td>
#       <td>-0.4715</td>
#       <td>-0.4286</td>
#       <td>-0.5225</td>
#       <td>-0.0570</td>
#       <td>-0.4286</td>
#       <td>-0.2270</td>
#       <td>-0.1624</td>
#       <td>-0.6354</td>
#       <td>-0.0379</td>
#       <td>-0.4347</td>
#       <td>-0.0655</td>
#       <td>-0.1897</td>
#       <td>-0.5097</td>
#       <td>-0.6494</td>
#       <td>-0.5086</td>
#       <td>-0.5284</td>
#       <td>-0.5266</td>
#       <td>-0.2738</td>
#       <td>-0.2739</td>
#       <td>-0.5438</td>
#       <td>-0.2198</td>
#       <td>-0.4960</td>
#       <td>-0.1548</td>
#       <td>-0.8717</td>
#       <td>-0.2330</td>
#       <td>-0.5107</td>
#       <td>-0.2764</td>
#       <td>-0.1277</td>
#       <td>1.0448</td>
#       <td>-0.4711</td>
#       <td>-0.1395</td>
#       <td>-0.5013</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.0</td>
#       <td>-0.8965</td>
#       <td>-0.4213</td>
#       <td>-0.6408</td>
#       <td>-0.5953</td>
#       <td>-0.4715</td>
#       <td>-0.4286</td>
#       <td>-0.5225</td>
#       <td>-0.0570</td>
#       <td>-0.4286</td>
#       <td>-0.2270</td>
#       <td>-0.1624</td>
#       <td>-0.6354</td>
#       <td>-0.0379</td>
#       <td>-0.4347</td>
#       <td>-0.0655</td>
#       <td>-0.1897</td>
#       <td>-0.5097</td>
#       <td>-0.6494</td>
#       <td>-0.5086</td>
#       <td>-0.5284</td>
#       <td>-0.5266</td>
#       <td>-0.2738</td>
#       <td>-0.2739</td>
#       <td>-0.5438</td>
#       <td>-0.2198</td>
#       <td>-0.4960</td>
#       <td>-0.1548</td>
#       <td>-0.8717</td>
#       <td>-0.2330</td>
#       <td>-0.5107</td>
#       <td>-0.2764</td>
#       <td>-0.1277</td>
#       <td>1.0448</td>
#       <td>-0.4711</td>
#       <td>-0.1395</td>
#       <td>-0.5013</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>3.0</td>
#       <td>-0.8965</td>
#       <td>-0.4213</td>
#       <td>-0.6408</td>
#       <td>-0.5953</td>
#       <td>-0.4715</td>
#       <td>-0.4286</td>
#       <td>-0.5225</td>
#       <td>-0.0570</td>
#       <td>-0.4286</td>
#       <td>-0.2270</td>
#       <td>-0.1624</td>
#       <td>-0.6354</td>
#       <td>-0.0379</td>
#       <td>-0.4347</td>
#       <td>-0.0655</td>
#       <td>-0.1897</td>
#       <td>-0.5097</td>
#       <td>-0.6494</td>
#       <td>-0.5086</td>
#       <td>-0.5284</td>
#       <td>-0.5266</td>
#       <td>-0.2738</td>
#       <td>-0.2739</td>
#       <td>-0.5438</td>
#       <td>-0.2198</td>
#       <td>-0.4960</td>
#       <td>-0.1548</td>
#       <td>-0.8717</td>
#       <td>-0.2330</td>
#       <td>-0.5107</td>
#       <td>-0.2764</td>
#       <td>-0.1277</td>
#       <td>1.0448</td>
#       <td>-0.4711</td>
#       <td>-0.1395</td>
#       <td>-0.5013</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>3.0</td>
#       <td>-0.8965</td>
#       <td>-0.4213</td>
#       <td>-0.6408</td>
#       <td>-0.5953</td>
#       <td>-0.4715</td>
#       <td>-0.4286</td>
#       <td>-0.5225</td>
#       <td>-0.0570</td>
#       <td>-0.4286</td>
#       <td>-0.2270</td>
#       <td>-0.1624</td>
#       <td>-0.6354</td>
#       <td>-0.0379</td>
#       <td>-0.4347</td>
#       <td>-0.0655</td>
#       <td>-0.1897</td>
#       <td>-0.5097</td>
#       <td>-0.6494</td>
#       <td>-0.5086</td>
#       <td>-0.5284</td>
#       <td>-0.5266</td>
#       <td>-0.2738</td>
#       <td>-0.2739</td>
#       <td>-0.5438</td>
#       <td>-0.2198</td>
#       <td>-0.4960</td>
#       <td>-0.1548</td>
#       <td>-0.8717</td>
#       <td>-0.2330</td>
#       <td>-0.5107</td>
#       <td>-0.2764</td>
#       <td>-0.1277</td>
#       <td>1.0448</td>
#       <td>-0.4711</td>
#       <td>-0.1395</td>
#       <td>-0.5013</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.validate(learn.data.train_dl)
# Out:
# [0.5017549, tensor(0.7538)]

# %%
preds,y,losses = learn.get_preds(with_loss=True)

# %%
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.confusion_matrix()
# Out:
# array([[ 2518, 14139],
#        [ 4142, 46697]], dtype=int64)

# %% [markdown]
# # Unfreezing, fine-tuning, and learning rates

# %%
learn.unfreeze()

# %%
learn.load('fastai_exp_3')
# Out:
# Learner(data=TabularDataBunch;
#
# Train: LabelList (1061364 items)
# x: TabularList
# MutatorClass 2; returnType 3.0; ccmaintainabilityIndex -0.8965; ppdistance -0.4213; ppfanout -0.6408; ccexternalMethodCalls -0.5953; mmhalsteadVocabulary -0.4715; cchalsteadCumulativeVolume -0.4286; pptcc -0.5225; numAssertInTM -0.0570; cchalsteadCumulativeBugs -0.4286; mmnumberOfExpressions -0.2270; ccmaintainabilityIndexNC -0.1624; ppRVF -0.6354; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex -0.1897; pploc -0.5097; ccimportedPackages -0.6494; ppnumberOfStatements -0.5086; ppnumberOfMethods -0.5284; ccunweightedClassSize -0.5266; mmhalsteadDifficulty -0.2738; ccfanIn -0.2739; ppmaxcc -0.5438; numTestCover -0.2198; ppmaintainabilityIndexNC -0.4960; cchalsteadEffort -0.1548; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5107; mmexternalMethodsCalled -0.2764; ppavcc -0.1277; ppinstability 1.0448; ccnumberOfStatements -0.4711; mmhalsteadEffort -0.1395; ppfanin -0.5013; ,MutatorClass 6; returnType 3.0; ccmaintainabilityIndex -0.8965; ppdistance -0.4213; ppfanout -0.6408; ccexternalMethodCalls -0.5953; mmhalsteadVocabulary -0.4715; cchalsteadCumulativeVolume -0.4286; pptcc -0.5225; numAssertInTM -0.0570; cchalsteadCumulativeBugs -0.4286; mmnumberOfExpressions -0.2270; ccmaintainabilityIndexNC -0.1624; ppRVF -0.6354; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex -0.1897; pploc -0.5097; ccimportedPackages -0.6494; ppnumberOfStatements -0.5086; ppnumberOfMethods -0.5284; ccunweightedClassSize -0.5266; mmhalsteadDifficulty -0.2738; ccfanIn -0.2739; ppmaxcc -0.5438; numTestCover -0.2198; ppmaintainabilityIndexNC -0.4960; cchalsteadEffort -0.1548; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5107; mmexternalMethodsCalled -0.2764; ppavcc -0.1277; ppinstability 1.0448; ccnumberOfStatements -0.4711; mmhalsteadEffort -0.1395; ppfanin -0.5013; ,MutatorClass 6; returnType 3.0; ccmaintainabilityIndex -0.8965; ppdistance -0.4213; ppfanout -0.6408; ccexternalMethodCalls -0.5953; mmhalsteadVocabulary -0.4715; cchalsteadCumulativeVolume -0.4286; pptcc -0.5225; numAssertInTM -0.0570; cchalsteadCumulativeBugs -0.4286; mmnumberOfExpressions -0.2270; ccmaintainabilityIndexNC -0.1624; ppRVF -0.6354; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex -0.1897; pploc -0.5097; ccimportedPackages -0.6494; ppnumberOfStatements -0.5086; ppnumberOfMethods -0.5284; ccunweightedClassSize -0.5266; mmhalsteadDifficulty -0.2738; ccfanIn -0.2739; ppmaxcc -0.5438; numTestCover -0.2198; ppmaintainabilityIndexNC -0.4960; cchalsteadEffort -0.1548; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5107; mmexternalMethodsCalled -0.2764; ppavcc -0.1277; ppinstability 1.0448; ccnumberOfStatements -0.4711; mmhalsteadEffort -0.1395; ppfanin -0.5013; ,MutatorClass 0; returnType 3.0; ccmaintainabilityIndex -0.8965; ppdistance -0.4213; ppfanout -0.6408; ccexternalMethodCalls -0.5953; mmhalsteadVocabulary -0.4715; cchalsteadCumulativeVolume -0.4286; pptcc -0.5225; numAssertInTM -0.0570; cchalsteadCumulativeBugs -0.4286; mmnumberOfExpressions -0.2270; ccmaintainabilityIndexNC -0.1624; ppRVF -0.6354; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex -0.1897; pploc -0.5097; ccimportedPackages -0.6494; ppnumberOfStatements -0.5086; ppnumberOfMethods -0.5284; ccunweightedClassSize -0.5266; mmhalsteadDifficulty -0.2738; ccfanIn -0.2739; ppmaxcc -0.5438; numTestCover -0.2198; ppmaintainabilityIndexNC -0.4960; cchalsteadEffort -0.1548; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5107; mmexternalMethodsCalled -0.2764; ppavcc -0.1277; ppinstability 1.0448; ccnumberOfStatements -0.4711; mmhalsteadEffort -0.1395; ppfanin -0.5013; ,MutatorClass 0; returnType 3.0; ccmaintainabilityIndex -0.8965; ppdistance -0.4213; ppfanout -0.6408; ccexternalMethodCa ...
# y: CategoryList
# True,True,True,True,True
# Path: ..\docs\dumps;
#
# Valid: LabelList (67496 items)
# x: TabularList
# MutatorClass 3; returnType 0.0; ccmaintainabilityIndex 0.3631; ppdistance -0.9766; ppfanout 0.1041; ccexternalMethodCalls 1.7755; mmhalsteadVocabulary -0.4591; cchalsteadCumulativeVolume 0.4999; pptcc -0.4594; numAssertInTM -0.0570; cchalsteadCumulativeBugs 0.4999; mmnumberOfExpressions -0.2237; ccmaintainabilityIndexNC 0.5885; ppRVF -0.6625; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex 1.5925; pploc -0.4438; ccimportedPackages 4.7667; ppnumberOfStatements -0.4594; ppnumberOfMethods -0.4224; ccunweightedClassSize 1.8486; mmhalsteadDifficulty -0.3429; ccfanIn -0.2471; ppmaxcc -0.5069; numTestCover -0.2198; ppmaintainabilityIndexNC 0.7572; cchalsteadEffort -0.1304; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5222; mmexternalMethodsCalled -0.2526; ppavcc -0.3172; ppinstability 1.6635; ccnumberOfStatements 0.5421; mmhalsteadEffort -0.1397; ppfanin -0.4352; ,MutatorClass 0; returnType 0.0; ccmaintainabilityIndex 0.3631; ppdistance -0.9766; ppfanout 0.1041; ccexternalMethodCalls 1.7755; mmhalsteadVocabulary -0.4591; cchalsteadCumulativeVolume 0.4999; pptcc -0.4594; numAssertInTM -0.0570; cchalsteadCumulativeBugs 0.4999; mmnumberOfExpressions -0.2237; ccmaintainabilityIndexNC 0.5885; ppRVF -0.6625; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex 1.5925; pploc -0.4438; ccimportedPackages 4.7667; ppnumberOfStatements -0.4594; ppnumberOfMethods -0.4224; ccunweightedClassSize 1.8486; mmhalsteadDifficulty -0.3429; ccfanIn -0.2471; ppmaxcc -0.5069; numTestCover -0.2198; ppmaintainabilityIndexNC 0.7572; cchalsteadEffort -0.1304; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5222; mmexternalMethodsCalled -0.2526; ppavcc -0.3172; ppinstability 1.6635; ccnumberOfStatements 0.5421; mmhalsteadEffort -0.1397; ppfanin -0.4352; ,MutatorClass 1; returnType 0.0; ccmaintainabilityIndex 0.3631; ppdistance -0.9766; ppfanout 0.1041; ccexternalMethodCalls 1.7755; mmhalsteadVocabulary -0.4591; cchalsteadCumulativeVolume 0.4999; pptcc -0.4594; numAssertInTM -0.0570; cchalsteadCumulativeBugs 0.4999; mmnumberOfExpressions -0.2237; ccmaintainabilityIndexNC 0.5885; ppRVF -0.6625; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex 1.5925; pploc -0.4438; ccimportedPackages 4.7667; ppnumberOfStatements -0.4594; ppnumberOfMethods -0.4224; ccunweightedClassSize 1.8486; mmhalsteadDifficulty -0.3429; ccfanIn -0.2471; ppmaxcc -0.5069; numTestCover -0.2198; ppmaintainabilityIndexNC 0.7572; cchalsteadEffort -0.1304; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5222; mmexternalMethodsCalled -0.2526; ppavcc -0.3172; ppinstability 1.6635; ccnumberOfStatements 0.5421; mmhalsteadEffort -0.1397; ppfanin -0.4352; ,MutatorClass 1; returnType 0.0; ccmaintainabilityIndex 0.3631; ppdistance -0.9766; ppfanout 0.1041; ccexternalMethodCalls 1.7755; mmhalsteadVocabulary -0.4591; cchalsteadCumulativeVolume 0.4999; pptcc -0.4594; numAssertInTM -0.0570; cchalsteadCumulativeBugs 0.4999; mmnumberOfExpressions -0.2237; ccmaintainabilityIndexNC 0.5885; ppRVF -0.6625; numExecuted -0.0379; mmvariablesReferenced -0.4347; numAssertInTC -0.0655; ppmaintainabilityIndex 1.5925; pploc -0.4438; ccimportedPackages 4.7667; ppnumberOfStatements -0.4594; ppnumberOfMethods -0.4224; ccunweightedClassSize 1.8486; mmhalsteadDifficulty -0.3429; ccfanIn -0.2471; ppmaxcc -0.5069; numTestCover -0.2198; ppmaintainabilityIndexNC 0.7572; cchalsteadEffort -0.1304; ppabstractness -0.8717; mminstanceVariablesReferenced -0.2330; ppnumberOfClasses -0.5222; mmexternalMethodsCalled -0.2526; ppavcc -0.3172; ppinstability 1.6635; ccnumberOfStatements 0.5421; mmhalsteadEffort -0.1397; ppfanin -0.4352; ,MutatorClass 8; returnType 0.0; ccmaintainabilityIndex 0.3631; ppdistance -0.9766; ppfanout 0.1041; ccexternalMethodCalls 1.7755; mmhalsteadVocabulary -0.4591; ccha ...
# y: CategoryList
# True,True,False,True,True
# Path: ..\docs\dumps;
#
# Test: None, model=TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(18, 8)
#     (1): Embedding(22, 10)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=54, out_features=200, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=200, out_features=100, bias=True)
#     (4): ReLU(inplace=True)
#     (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=100, out_features=2, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x0000020E99FC7C80>, Precision(average='binary', pos_label=1, eps=1e-09), Recall(average='binary', pos_label=1, eps=1e-09), MatthewsCorreff(), AUROC()], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('../docs/dumps'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Embedding(18, 8)
#   (1): Embedding(22, 10)
#   (2): Dropout(p=0.0, inplace=False)
#   (3): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Linear(in_features=54, out_features=200, bias=True)
#   (5): ReLU(inplace=True)
#   (6): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Linear(in_features=200, out_features=100, bias=True)
#   (8): ReLU(inplace=True)
#   (9): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Linear(in_features=100, out_features=2, bias=True)
# )], add_time=True, silent=False)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>matthews_correff</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='92' class='' max='16583' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.55% [92/16583 00:58<2:54:39 1.5646]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>matthews_correff</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.419214</td>
#       <td>0.559233</td>
#       <td>0.742785</td>
#       <td>0.766087</td>
#       <td>0.947953</td>
#       <td>0.110552</td>
#       <td>0.624168</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.413836</td>
#       <td>0.558366</td>
#       <td>0.729154</td>
#       <td>0.767588</td>
#       <td>0.918527</td>
#       <td>0.100758</td>
#       <td>0.627974</td>
#       <td>07:29</td>
#     </tr>
#   </tbody>
# </table>
